# %%
import pandas as pd
import numpy as np

#loading data into datafram
df = pd.read_csv("Match_data.csv")

# sort based on the match date
df = df.sort_values(by=["date"])

print(df.head())
# Out:
#                                       id                  team1  \
# 14  cacf2d34-41b8-41dd-91ed-5183d880084c  Kolkata Knight Riders
# 17  208d68e5-3fab-4f3b-88e9-29ec4a02d3e2    Chennai Super Kings
# 16  91b007f3-c0af-493f-808a-3f4ae2d66e33    Sunrisers Hyderabad
# 18  c6e97609-d9c1-46eb-805a-e282b34f3bb1         Delhi Capitals
# 19  83d70527-5fc4-4fad-8dd2-b88b385f379e         Gujarat Titans
#
#                                      team2        date      score1  \
# 14  Royal Challengers Bengaluru, 1st Match  2025-03-22  174/8 (20)
# 17               Mumbai Indians, 3rd Match  2025-03-23  155/9 (20)
# 16             Rajasthan Royals, 2nd Match  2025-03-23  286/6 (20)
# 18         Lucknow Super Giants, 4th Match  2025-03-24  209/8 (20)
# 19                 Punjab Kings, 5th Match  2025-03-25  243/5 (20)
#
#           score2                                              venue
# 14  177/3 (16.2)                              Eden Gardens, Kolkata
# ...
